# %%
a = "Hi"
a
# Out:
# 'Hi'

# %%
import os
os.listdir()
# Out:
# ['.ipynb_checkpoints', 'InputFiles', 'Tryouts.ipynb', 'Tryouts.py']

# %%
import pandas

# %%
input_files_dir = os.getcwd()
input_files_dir
# Out:
# 'D:\\ModernLab\\Learning\\Python\\App2_MySql'

# %%
df1 = pandas.read_csv(input_files_dir + "\\InputFiles\\supermarkets.csv")
df1
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df2 = pandas.read_json(input_files_dir + "\\InputFiles\\supermarkets.json")
df2
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
# import xlrd
df3 = pandas.read_excel(input_files_dir + "\\InputFiles\\supermarkets.xlsx", engine="openpyxl")
df3
# Out:
#    ID          Address           City             State Country  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA
# 1   2   735 Dolores St  San Francisco          CA 94119     USA
# 2   3      332 Hill St  San Francisco  California 94114     USA
# 3   4     3995 23rd St  San Francisco          CA 94114     USA
# 4   5  1056 Sanchez St  San Francisco        California     USA
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA
#
#   Supermarket Name  Number of Employees
# 0          Madeira                    8
# 1      Bready Shop                   15
# 2      Super River                   25
# 3       Ben's Shop                   10
# 4          Sanchez                   12
# 5       Richvalley                   20

# %%
df4 = pandas.read_csv(input_files_dir + "\\InputFiles\\supermarkets-commas.txt")
df4
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df5 = pandas.read_csv(input_files_dir + "\\InputFiles\\supermarkets-commas.txt", )
df5
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df5 = pandas.read_csv(input_files_dir + "\\InputFiles\\supermarkets-semi-colons.txt", sep=";")
df5
# Out:
#    ID          Address           City             State Country          Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA       Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA   Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA   Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA    Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA       Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
pandas.read_csv?

# %%
df5["Employees"].sum()
# Out:
# 90

# %%
df5.set_index("ID")
# Out:
#             Address           City             State Country          Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA       Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA   Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA   Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA    Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA       Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df5.loc[2:5, "City":"Country"]
# Out:
#             City             State Country
# 2  San Francisco  California 94114     USA
# 3  San Francisco          CA 94114     USA
# 4  San Francisco        California     USA
# 5  San Francisco          CA 94114     USA

# %%
df5
# Out:
#    ID          Address           City             State Country          Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA       Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA   Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA   Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA    Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA       Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df5.drop("State", 1, inplace=False)
df5
# Out:
#    ID          Address           City             State Country          Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA       Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA   Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA   Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA    Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA       Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df5
# Out:
#    ID          Address           City             State Country          Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA       Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA   Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA   Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA    Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA       Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df5["Continent"] = df5.shape[0] * ["Asia"]
df5
# Out:
#    ID          Address           City             State Country          Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA       Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA   Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA   Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA    Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA       Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#    Employees Continent
# 0          8      Asia
# 1         15      Asia
# 2         25      Asia
# 3         10      Asia
# 4         12      Asia
# 5         20      Asia

# %%
from geopy.geocoders import ArcGIS

# %%
nom = ArcGIS()
n = nom.geocode("3666 21st St, San Francisco, CA 94114")

# %%
n.latitude
# Out:
# 37.756648011392286

# %%
df5["Address"] = df5["Address"] + ", " + df5["City"] + ", " + df5["State"]
df5
# Out:
#    ID                                       Address           City  \
# 0   1         3666 21st St, San Francisco, CA 94114  San Francisco
# 1   2       735 Dolores St, San Francisco, CA 94119  San Francisco
# 2   3  332 Hill St, San Francisco, California 94114  San Francisco
# 3   4         3995 23rd St, San Francisco, CA 94114  San Francisco
# 4   5    1056 Sanchez St, San Francisco, California  San Francisco
# 5   6      551 Alvarado St, San Francisco, CA 94114  San Francisco
#
#               State Country          Name  Employees Continent
# 0          CA 94114     USA       Madeira          8      Asia
# 1          CA 94119     USA   Bready Shop         15      Asia
# 2  California 94114     USA   Super River         25      Asia
# 3          CA 94114     USA    Ben's Shop         10      Asia
# 4        California     USA       Sanchez         12      Asia
# 5          CA 94114     USA    Richvalley         20      Asia

# %%
for i in df5["Address"]:
    loc = nom.geocode(i)
    print(loc.latitude, loc.longitude)
# Out:
# 37.756648011392286 -122.42937496976432
# 37.757819005175406 -122.42533698790956
# 37.755874990371936 -122.42881598064156
# 37.75292200397371 -122.43169700840102
# 37.75213100377104 -122.43002800384072
# 37.75351100030984 -122.43322896884439

# %%
home_loc = nom.geocode("3\169 Palaiyur veppanthattai( p.o & T.k, Palaiyur, Tamil Nadu 621116")
home_loc
# Out:
# Location(621116, (11.36329500000005, 78.83154897100007, 0.0))

# %%
df5["Co-ords"] = df5["Address"].apply(nom.geocode)
df5["Co-ords"][0]
# Out:
# Location(3666 21st St, San Francisco, California, 94114, (37.756648011392286, -122.42937496976432, 0.0))

# %%
df5["latitude"] = df5["Co-ords"].apply(lambda x: x.latitude)
df5["longitude"] = df5["Co-ords"].apply(lambda x: x.longitude)
df5
# Out:
#    ID                                       Address           City  \
# 0   1         3666 21st St, San Francisco, CA 94114  San Francisco
# 1   2       735 Dolores St, San Francisco, CA 94119  San Francisco
# 2   3  332 Hill St, San Francisco, California 94114  San Francisco
# 3   4         3995 23rd St, San Francisco, CA 94114  San Francisco
# 4   5    1056 Sanchez St, San Francisco, California  San Francisco
# 5   6      551 Alvarado St, San Francisco, CA 94114  San Francisco
#
#               State Country          Name  Employees Continent  \
# 0          CA 94114     USA       Madeira          8      Asia
# 1          CA 94119     USA   Bready Shop         15      Asia
# 2  California 94114     USA   Super River         25      Asia
# 3          CA 94114     USA    Ben's Shop         10      Asia
# 4        California     USA       Sanchez         12      Asia
# 5          CA 94114     USA    Richvalley         20      Asia
#
# ...
